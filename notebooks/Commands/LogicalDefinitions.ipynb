# %% [markdown]
# # OAK logical-definitions command
#
# This notebook is intended as a supplement to the [main OAK CLI docs](https://incatools.github.io/ontology-access-kit/cli.html).
#
# This notebook provides examples for the `logical-definitions` command, which can be used to **lookup and summarize logical defs**
#
# For more on logical definitions, see [Logical Definitions](https://incatools.github.io/ontology-access-kit/guide/logical-definitions.html) in the OAK guide.
#
# ## Help Option
#
# You can get help on any OAK command using `--help`

# %%
# !runoak logical-definitions --help
# Out:
# Usage: runoak logical-definitions [OPTIONS] [TERMS]...
#
#   Show all logical definitions for a term or terms.
#
#   To show all logical definitions in an ontology, pass the ".all" query term
#
#   Example; first create an alias:
#
#       alias pato="runoak -i obo:sqlite:pato"
#
#   Then run the query:
#
#       pato logical-definitions .all
#
#   By default, ".all" will query all axioms for all terms including merged
#   terms; to restrict to only the current terms, use an ID query:
#
#       pato logical-definitions i^PATO
#
#   You can also restrict to branches:
#
#       pato logical-definitions .desc//p=i "physical object quality"
#
#   By default, the output is a subset of OboGraph datamodel rendered as YAML,
#   e.g.
#
#     definedClassId: PATO:0045071     genusIds:     - PATO:0001439
#     restrictions:     - fillerId: PATO:0000461       propertyId: RO:0015010
#
#   You can also specify CSV to generate a flattened form of this.
#
#   Example:
#
#       pato logical-definitions .all --output-type csv
#
#   You can optionally choose to "--matrix-axes" to transform the output to a
#   matrix form. This is a comma-separated pair of axes, where each element is a
#   logical definition element type: "f" for filler, "p" for predicate, "g" for
#   genus, "d" for defined class.
#
#   Example:
#
#   - Each property/predicate is a column - For repeated properties, columns of
#   the form prop_1, prop_2, ... are generated
#
#   Example:
#
#       pato logical-definitions .all  --matrix-axes d,p --output-type csv
#
#   This will generate a row for each defined class with a logical definition,
#   with columns for each predicate ("genus" is treated as a predicate here).
#
#   Limitations:
#
#   Currently this only works for definitions that follow a basic genus-
#   differentia pattern, which is what is currently represented in the OboGraph
#   datamodel.
#
#   Consider using the "axioms" command for inspection of complex nested OWL
#   axioms.
#
#   Python API:
#
#      https://incatools.github.io/ontology-access-kit/interfaces/obograph
#
#   Data model:
#
#      https://w3id.org/oak/obograph
#
# Options:
#   --unmelt / --no-unmelt          Flatten to a wide table  [default: no-
#                                   unmelt]
#   --matrix-axes TEXT              If specified, transform results to matrix
#                                   using these row and column axes. Examples:
#                                   d,p; f,g
#   -p, --predicates TEXT           A comma-separated list of predicates. This
#                                   may be a shorthand (i, p) or CURIE
#   --autolabel / --no-autolabel    If set, results will automatically have
#                                   labels assigned  [default: autolabel]
#   -O, --output-type TEXT          Desired output type
#   -o, --output FILENAME           Output file, e.g. obo file
#   --if-absent [absent-only|present-only]
#                                   determines behavior when the value is not
#                                   present or is empty.
#   -S, --set-value TEXT            the value to set for all terms for the given
#                                   property.
#   --help                          Show this message and exit.

# %% [markdown]
# ## Set up an alias
#
# For convenience we will set up an alias for use in this notebook

# %%
alias uberon runoak -i sqlite:obo:uberon

# %% [markdown]
# ## Fetching logical definitions for individual terms
#
# First we will pass in a simple list of terms to the command.
#
# Like most OAK commands, this command accepts lists of either IDs, labels, queries, or boolean combinations thereof

# %%
uberon logical-definitions fingernail toenail
# Out:
# definedClassId: UBERON:0009565
# genusIds:
# - UBERON:0001705
# restrictions:
# - fillerId: UBERON:0002389
#   propertyId: BFO:0000050
#
# ---
# definedClassId: UBERON:0009567
# genusIds:
# - UBERON:0001705
# restrictions:
# - fillerId: UBERON:0001466
#   propertyId: BFO:0000050

# %%
uberon logical-definitions fingernail toenail -O csv
# Out:
# definedClassId	definedClassId_label	genusIds	genusIds_label	restrictions	restrictionsPropertyIds	restrictionsPropertyIds_label	restrictionsFillerIds	restrictionsFillerIds_label
# UBERON:0009565	nail of manual digit	UBERON:0001705	nail	BFO:0000050=UBERON:0002389	BFO:0000050	part of	UBERON:0002389	manual digit
# UBERON:0009567	nail of pedal digit	UBERON:0001705	nail	BFO:0000050=UBERON:0001466	BFO:0000050	part of	UBERON:0001466	pedal digit

# %%
uberon logical-definitions fingernail toenail -O obo
# Out:
# [Term]
# id: UBERON:0009565 ! nail of manual digit
# intersection_of: UBERON:0001705 ! nail
# intersection_of: BFO:0000050 UBERON:0002389 ! manual digit
#
#
# [Term]
# id: UBERON:0009567 ! nail of pedal digit
# intersection_of: UBERON:0001705 ! nail
# intersection_of: BFO:0000050 UBERON:0001466 ! pedal digit

# %% [markdown]
# ## Matrix views
#
# We can use the `--matrix-axes` option to summarize a large collection of logical definitions as a wide table.
#
# This takes two values, separated by a comma:
#
# - d: defined_class
# - f: filler
# - g: genus
# - p: predicate
#
# For example `f,g` will create a matrix whose rows are fillers and whose columns are genus terms (the cell values
# will be the defined class)

# %%
uberon logical-definitions .desc//p=i,p digit .and .desc//p=i "bone element" --matrix-axes f,g -O csv -o output/uberon-digit-defs-gd.tsv

# %%
import pandas as pd
df = pd.read_csv("output/uberon-digit-defs-gd.tsv", sep="\t")
df
# Out:
#             filler                     filler_label  \
# 0   UBERON:0002389                     manual digit
# 1   UBERON:0002387                              pes
# 2   UBERON:0001466                      pedal digit
# 3   UBERON:0003622                   manual digit 2
# 4   UBERON:0003623                   manual digit 3
# 5   UBERON:0003624                   manual digit 4
# 6   UBERON:0003625                   manual digit 5
# 7   UBERON:0003632                    pedal digit 2
# 8   UBERON:0003633                    pedal digit 3
# 9   UBERON:0003634                    pedal digit 4
# 10  UBERON:0003635                    pedal digit 5
# 11  UBERON:0003631                    pedal digit 1
# 12  UBERON:0001463                   manual digit 1
# 13  UBERON:0002481                      bone tissue
# 14  UBERON:0004301                   middle phalanx
# 15  UBERON:0003221                          phalanx
# 16  UBERON:0003821                  metapodium bone
# 17  UBERON:5006048  digit 1 plus metapodial segment
# 18  UBERON:5006049  digit 2 plus metapodial segment
# 19  UBERON:5006050  digit 3 plus metapodial segment
# 20  UBERON:5006051  digit 4 plus metapodial segment
# 21  UBERON:5006052  digit 5 plus metapodial segment
# 22  UBERON:0006048                          digit 1
# 23  UBERON:0006049                          digit 2
# 24  UBERON:0006050                          digit 3
# 25  UBERON:0006051                          digit 4
# 26  UBERON:0006052                          digit 5
# 27  UBERON:0012137                    pedal digit 7
# 28  UBERON:0009563           pastern region of limb
# 29  UBERON:0000983                metatarsus region
# 30  UBERON:0016866  digit 6 plus metapodial segment
# 31  UBERON:0016867  digit 7 plus metapodial segment
# 32  UBERON:0016868  digit 8 plus metapodial segment
#
#                           phalanx                  phalanx_label  \
# 0                  UBERON:0001436               phalanx of manus
# 1                  UBERON:0001449                 phalanx of pes
# 2                             NaN                            NaN
# 3                  UBERON:0003636         manual digit 2 phalanx
# 4                  UBERON:0003637         manual digit 3 phalanx
# 5                  UBERON:0003638         manual digit 4 phalanx
# 6                  UBERON:0003639         manual digit 5 phalanx
# 7                  UBERON:0003641          pedal digit 2 phalanx
# 8                  UBERON:0003642          pedal digit 3 phalanx
# 9                  UBERON:0003862          pedal digit 4 phalanx
# 10                 UBERON:0003863          pedal digit 5 phalanx
# 11                 UBERON:0003640          pedal digit 1 phalanx
# 12                 UBERON:0003620         manual digit 1 phalanx
# 13                            NaN                            NaN
# 14  UBERON:0004300|UBERON:0004300  distal phalanx|distal phalanx
# 15  UBERON:0004301|UBERON:0004301  middle phalanx|middle phalanx
# 16                 UBERON:0004302               proximal phalanx
# 17                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            NaN                            NaN
# 20                            NaN                            NaN
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 23                            NaN                            NaN
# 24                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 27                 UBERON:4100009          pedal digit 7 phalanx
# 28                 UBERON:0009558                   pastern bone
# 29                            NaN                            NaN
# 30                            NaN                            NaN
# 31                            NaN                            NaN
# 32                            NaN                            NaN
#
#                    middle_phalanx  \
# 0   UBERON:0003864|UBERON:0003864
# 1                             NaN
# 2                  UBERON:0003866
# 3                  UBERON:0004320
# 4                  UBERON:0004321
# 5                  UBERON:0004322
# 6                  UBERON:0004323
# 7                  UBERON:0004324
# 8                  UBERON:0004325
# 9                  UBERON:0004326
# 10                 UBERON:0004327
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                 UBERON:0014488
# 24                 UBERON:0014489
# 25                 UBERON:0014490
# 26                 UBERON:0014491
# 27                            NaN
# 28                            NaN
# 29                            NaN
# 30                            NaN
# 31                            NaN
# 32                            NaN
#
#                                middle_phalanx_label  distal_phalanx  \
# 0   middle phalanx of manus|middle phalanx of manus  UBERON:0003865
# 1                                               NaN             NaN
# 2                             middle phalanx of pes  UBERON:0003867
# 3                  middle phalanx of manual digit 2  UBERON:0004311
# 4                  middle phalanx of manual digit 3  UBERON:0004312
# 5                  middle phalanx of manual digit 4  UBERON:0004313
# 6                  middle phalanx of manual digit 5  UBERON:0004314
# 7                   middle phalanx of pedal digit 2  UBERON:0004316
# 8                   middle phalanx of pedal digit 3  UBERON:0004317
# 9                   middle phalanx of pedal digit 4  UBERON:0004318
# 10                  middle phalanx of pedal digit 5  UBERON:0004319
# 11                                              NaN  UBERON:0004315
# 12                                              NaN  UBERON:0004337
# 13                                              NaN             NaN
# 14                                              NaN             NaN
# 15                                              NaN             NaN
# 16                                              NaN             NaN
# 17                                              NaN             NaN
# 18                                              NaN             NaN
# 19                                              NaN             NaN
# 20                                              NaN             NaN
# 21                                              NaN             NaN
# 22                                              NaN  UBERON:0014483
# 23                        middle phalanx of digit 2  UBERON:0014484
# 24                        middle phalanx of digit 3  UBERON:0014485
# 25                        middle phalanx of digit 4  UBERON:0014486
# 26                        middle phalanx of digit 5  UBERON:0014487
# 27                                              NaN             NaN
# 28                                              NaN             NaN
# 29                                              NaN             NaN
# 30                                              NaN             NaN
# 31                                              NaN             NaN
# 32                                              NaN             NaN
#
#                 distal_phalanx_label    bone_element bone_element_label  ...  \
# 0            distal phalanx of manus  UBERON:0004249  manual digit bone  ...
# 1                                NaN             NaN                NaN  ...
# 2              distal phalanx of pes  UBERON:0004248   pedal digit bone  ...
# 3   distal phalanx of manual digit 2             NaN                NaN  ...
# 4   distal phalanx of manual digit 3             NaN                NaN  ...
# 5   distal phalanx of manual digit 4             NaN                NaN  ...
# 6   distal phalanx of manual digit 5             NaN                NaN  ...
# 7    distal phalanx of pedal digit 2             NaN                NaN  ...
# 8    distal phalanx of pedal digit 3             NaN                NaN  ...
# 9    distal phalanx of pedal digit 4             NaN                NaN  ...
# 10   distal phalanx of pedal digit 5             NaN                NaN  ...
# 11   distal phalanx of pedal digit 1             NaN                NaN  ...
# 12  distal phalanx of manual digit 1             NaN                NaN  ...
# 13                               NaN             NaN                NaN  ...
# 14                               NaN             NaN                NaN  ...
# 15                               NaN             NaN                NaN  ...
# 16                               NaN             NaN                NaN  ...
# 17                               NaN             NaN                NaN  ...
# 18                               NaN             NaN                NaN  ...
# 19                               NaN             NaN                NaN  ...
# 20                               NaN             NaN                NaN  ...
# 21                               NaN             NaN                NaN  ...
# 22         distal phalanx of digit 1             NaN                NaN  ...
# 23         distal phalanx of digit 2             NaN                NaN  ...
# 24         distal phalanx of digit 3             NaN                NaN  ...
# 25         distal phalanx of digit 4             NaN                NaN  ...
# 26         distal phalanx of digit 5             NaN                NaN  ...
# 27                               NaN             NaN                NaN  ...
# 28                               NaN             NaN                NaN  ...
# 29                               NaN             NaN                NaN  ...
# 30                               NaN             NaN                NaN  ...
# 31                               NaN             NaN                NaN  ...
# 32                               NaN             NaN                NaN  ...
#
#    manual_digit_3_metacarpus_endochondral_element  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                 UBERON:0003647
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
#
#    manual_digit_3_metacarpus_endochondral_element_label  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                         metacarpal bone of digit 3
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#    manual_digit_1_metacarpus_endochondral_element  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                 UBERON:0003645
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
#
#    manual_digit_1_metacarpus_endochondral_element_label metapodium_bone  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6                                                 NaN               NaN
# 7                                                 NaN               NaN
# 8                                                 NaN               NaN
# 9                                                 NaN               NaN
# 10                                                NaN               NaN
# 11                                                NaN               NaN
# 12                                                NaN               NaN
# 13                         metacarpal bone of digit 1               NaN
# 14                                                NaN               NaN
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN    UBERON:0013581
# 18                                                NaN    UBERON:0013582
# 19                                                NaN    UBERON:0013583
# 20                                                NaN    UBERON:0013584
# 21                                                NaN    UBERON:0013585
# 22                                                NaN               NaN
# 23                                                NaN               NaN
# 24                                                NaN               NaN
# 25                                                NaN               NaN
# 26                                                NaN               NaN
# 27                                                NaN               NaN
# 28                                                NaN               NaN
# 29                                                NaN               NaN
# 30                                                NaN    UBERON:4200154
# 31                                                NaN    UBERON:4200155
# 32                                                NaN    UBERON:4200156
#
#    metapodium_bone_label manual_digit_2_metacarpus_endochondral_element  \
# 0                    NaN                                            NaN
# 1                    NaN                                            NaN
# 2                    NaN                                            NaN
# 3                    NaN                                            NaN
# 4                    NaN                                            NaN
# 5                    NaN                                            NaN
# 6                    NaN                                            NaN
# 7                    NaN                                            NaN
# 8                    NaN                                            NaN
# 9                    NaN                                            NaN
# 10                   NaN                                            NaN
# 11                   NaN                                            NaN
# 12                   NaN                                            NaN
# 13                   NaN                                 UBERON:0003646
# 14                   NaN                                            NaN
# 15                   NaN                                            NaN
# 16                   NaN                                            NaN
# 17     metapodium bone 1                                            NaN
# 18     metapodium bone 2                                            NaN
# 19     metapodium bone 3                                            NaN
# 20     metapodium bone 4                                            NaN
# 21     metapodium bone 5                                            NaN
# 22                   NaN                                            NaN
# 23                   NaN                                            NaN
# 24                   NaN                                            NaN
# 25                   NaN                                            NaN
# 26                   NaN                                            NaN
# 27                   NaN                                            NaN
# 28                   NaN                                            NaN
# 29                   NaN                                            NaN
# 30     metapodium bone 6                                            NaN
# 31     metapodium bone 7                                            NaN
# 32     metapodium bone 8                                            NaN
#
#    manual_digit_2_metacarpus_endochondral_element_label metapodium_bone_6  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                         metacarpal bone of digit 2                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
# 26                                                NaN                 NaN
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                                NaN      UBERON:4200153
# 30                                                NaN                 NaN
# 31                                                NaN                 NaN
# 32                                                NaN                 NaN
#
#        metapodium_bone_6_label
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29  metatarsal bone of digit 6
# 30                         NaN
# 31                         NaN
# 32                         NaN
#
# [33 rows x 42 columns]

# %% [markdown]
# We can flip this around, and have each row be a defined class (`d`), and each column be a predicate (`p`)

# %%
uberon logical-definitions .desc//p=i,p digit .and .desc//p=i "bone element" --matrix-axes d,p -O csv -o output/uberon-digit-defs-dp.tsv

# %%
df = pd.read_csv("output/uberon-digit-defs-dp.tsv", sep="\t")
df
# Out:
#      defined_class         defined_class_label           genus  \
# 0   UBERON:0001436            phalanx of manus  UBERON:0003221
# 1   UBERON:0001449              phalanx of pes  UBERON:0003221
# 2   UBERON:0003864     middle phalanx of manus  UBERON:0004301
# 3   UBERON:0003865     distal phalanx of manus  UBERON:0004300
# 4   UBERON:0003866       middle phalanx of pes  UBERON:0004301
# ..             ...                         ...             ...
# 86  UBERON:4200154           metapodium bone 6  UBERON:0003821
# 87  UBERON:4200155           metapodium bone 7  UBERON:0003821
# 88  UBERON:4200156           metapodium bone 8  UBERON:0003821
# 89  UBERON:4200157  metatarsal bone of digit 7  UBERON:4200155
# 90  UBERON:4200158  metatarsal bone of digit 8  UBERON:4200156
#
#           genus_label         part_of                    part_of_label  \
# 0             phalanx  UBERON:0002389                     manual digit
# 1             phalanx  UBERON:0002387                              pes
# 2      middle phalanx  UBERON:0002389                     manual digit
# 3      distal phalanx  UBERON:0002389                     manual digit
# 4      middle phalanx  UBERON:0001466                      pedal digit
# ..                ...             ...                              ...
# 86    metapodium bone  UBERON:0016866  digit 6 plus metapodial segment
# 87    metapodium bone  UBERON:0016867  digit 7 plus metapodial segment
# 88    metapodium bone  UBERON:0016868  digit 8 plus metapodial segment
# 89  metapodium bone 7  UBERON:0000983                metatarsus region
# 90  metapodium bone 8  UBERON:0000983                metatarsus region
#
#    distally_connected_to distally_connected_to_label connected_to  \
# 0                    NaN                         NaN          NaN
# 1                    NaN                         NaN          NaN
# 2                    NaN                         NaN          NaN
# 3                    NaN                         NaN          NaN
# 4                    NaN                         NaN          NaN
# ..                   ...                         ...          ...
# 86                   NaN                         NaN          NaN
# 87                   NaN                         NaN          NaN
# 88                   NaN                         NaN          NaN
# 89                   NaN                         NaN          NaN
# 90                   NaN                         NaN          NaN
#
#    connected_to_label proximally_connected_to proximally_connected_to_label  \
# 0                 NaN                     NaN                           NaN
# 1                 NaN                     NaN                           NaN
# 2                 NaN                     NaN                           NaN
# 3                 NaN                     NaN                           NaN
# 4                 NaN                     NaN                           NaN
# ..                ...                     ...                           ...
# 86                NaN                     NaN                           NaN
# 87                NaN                     NaN                           NaN
# 88                NaN                     NaN                           NaN
# 89                NaN                     NaN                           NaN
# 90                NaN                     NaN                           NaN
#
#    composed_primarily_of composed_primarily_of_label
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
# ..                   ...                         ...
# 86                   NaN                         NaN
# 87                   NaN                         NaN
# 88                   NaN                         NaN
# 89                   NaN                         NaN
# 90                   NaN                         NaN
#
# [91 rows x 14 columns]

# %% [markdown]
# ## Analyzing and gap filling
#
# OAK has experimental features for analyzing and gap-filling logical definitions; these are not yet exposed on the command line
