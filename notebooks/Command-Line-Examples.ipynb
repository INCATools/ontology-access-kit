# %% [markdown]
# # Command Line Examples
#
# All lines starting `!` are commands that you can execute yourself on the command line

# %%
# !pwd
# Out:
# /Users/cjm/repos/ontology-access-kit/notebooks

# %%
# !runoak --help
# Out:
# Usage: runoak [OPTIONS] COMMAND [ARGS]...
#
#   Run the oaklib Command Line.
#
#   A subcommand must be passed - for example: ancestors, terms, ...
#
#   Most commands require an input ontology to be specified:
#
#       runoak -i <INPUT SPECIFICATION> SUBCOMMAND <SUBCOMMAND OPTIONS AND
#       ARGUMENTS>
#
#   Get help on any command, e.g:
#
#       runoak viz -h
#
# Options:
#   -v, --verbose
#   -q, --quiet TEXT
#   -i, --input TEXT       path to input implementation specification.
#   -I, --input-type TEXT  Input type.
#   -a, --add TEXT         additional implementation specification.
#   --help                 Show this message and exit.
#
# Commands:
#   add-taxon-constraints  Test candidate taxon constraints
#   aliases                List all aliases in the ontology
#   all-relationships      Show all relationships for all terms
#   all-similarity         All by all similarity
#   all-subsets            Shows all subsets
#   ancestors              List all ancestors
#   annotate               Annotate a piece of text using a Named Entity...
#   axioms                 List all axioms
#   check-definitions      Check definitions
#   combine                Perform set-wise combination operation on two...
#   convert                TODO
#   descendants            List all descendants of a term
#   extract-subset         Extracts a subset
#   extract-triples        Extracts a subontology as triples
#   info                   Show info on terms
#   lexmatch               Generates lexical index and mappings
#   list-subset            Shows IDs in a given subset
#   mappings               List all SSSOM mappings in the ontology
#   migrate-curies         Rewires an ontology replacing all instances of...
#   ontologies             Shows ontologies
#   ontology-metadata      Shows ontology metadata
#   ontology-versions      Shows ontology versions
#   relationships          Show all relationships for a term or terms
#   roots                  List all root in the ontology
#   search                 Searches ontology for entities that have a...
#   set-apikey             Sets an API key
#   similarity             Determine pairwise similarity between two terms...
#   subset-rollups         For each subset provide a mapping of each term...
#   taxon-constraints      List all taxon constraints for a term or terms
#   term-mappings          List all SSSOM mappings for a term or terms
#   term-metadata          Shows term metadata
#   terms                  List all terms in the ontology
#   tree                   Display an ancestor graph as an ascii/markdown tree
#   validate               Validate an ontology against ontology metadata
#   validate-multiple      Validate multiple ontologies against ontology...
#   viz                    Visualizing an ancestor graph using obographviz

# %% [markdown]
# ## Ubergraph Examples
#
# Ubergraph is suitable for both graphy type operations as well as some inference/OWLy operations
#
# The default ubergraph endpoint is used, but you could also set up your own

# %% [markdown]
# ### Graphy operations

# %%
# all is-a (i.e. subClassOf between named classes) ancestors of a seed set
# !runoak  -i ubergraph: ancestors GO:0001750 CL:0000540 -p i
# Out:
# id	label
# BFO:0000002	continuant
# BFO:0000004	independent continuant
# BFO:0000040	material entity
# CARO:0000000	anatomical entity
# CARO:0030000	biological entity
# CL:0000000	cell
# CL:0000003	native cell
# CL:0000211	electrically active cell
# CL:0000255	eukaryotic cell
# CL:0000393	electrically responsive cell
# CL:0000404	electrically signaling cell
# CL:0000540	neuron
# CL:0000548	animal cell
# CL:0002319	neural cell
# CL:0002371	somatic cell
# COB:0000006	material entity
# COB:0000017	cell
# COB:0000018	native cell
# UBERON:0001062	anatomical entity
# GO:0005575	cellular_component
# GO:0001750	photoreceptor outer segment
# GO:0110165	cellular anatomical entity

# %%
# visualize starting from a seed set of terms
# !runoak  -i ubergraph: viz --no-view GO:0001750 CL:0000540 -p i,BFO:0000050 -o output/ug-test1.png -O png

# %% [markdown]
# ![img](output/ug-test1.png)

# %% [markdown]
# ### Gap Filling

# %%
# !runoak -i ubergraph: viz --gap-fill GO:0001750 CL:0000540 CL:0000000 NCBITaxon:9606 NCBITaxon:1 -p i,p -o output/ug-gap-fill1.png -O png

# %% [markdown]
# ![img](output/ug-gap-fill1.png)

# %% [markdown]
# ### Extracting triples
#
# The `extract-triples` command will perform a simplified version of robot extract

# %%
# !runoak  -i ubergraph:cl extract-triples CL:0000540 | grep -A10 owl:Class | head -50
# Out:
# ns1:CARO_0010004 a owl:Class ;
#     ns3:normalizedInformationContent 2.9759597027374216 ;
#     ns3:referenceCount 2189874 ;
#     rdfs:isDefinedBy ns1:caro.owl ;
#     rdfs:subClassOf ns1:CARO_0001010,
#         ns1:COB_0000022,
#         ns1:NCBITaxon_1,
#         ns1:OBI_0100026 ;
#     owl:equivalentClass ns1:COB_0000118 .
#
# ns1:CL_0000255 a owl:Class ;
#     rdfs:label "eukaryotic cell"^^xsd:string ;
#     ns3:normalizedInformationContent 38.474125635088676 ;
#     ns3:referenceCount 10487 ;
#     ns2:hasOBONamespace "cell"^^xsd:string ;
#     rdfs:isDefinedBy ns1:cl.owl ;
#     rdfs:subClassOf ns1:CARO_0000013,
#         ns1:CL_0000003,
#         ns1:COB_0000018 ;
#     owl:disjointWith ns1:CL_0000520 ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf [ ] ],
#         [ a owl:Class ;
#             owl:intersectionOf [ ] ] .
#
# ns1:CL_0000393 a owl:Class ;
#     rdfs:label "electrically responsive cell"^^xsd:string ;
#     ns1:IAO_0000115 "A cell whose function is determined by its response to an electric signal."^^xsd:string ;
#     ns3:normalizedInformationContent 40.249883390245465 ;
#     ns3:referenceCount 8028 ;
#     ns2:hasOBONamespace "cell"^^xsd:string ;
#     rdfs:isDefinedBy ns1:cl.owl ;
#     rdfs:subClassOf ns1:CL_0000211 .
#
# ns1:CL_0000404 a owl:Class ;
#     rdfs:label "electrically signaling cell"^^xsd:string ;
#     ns1:IAO_0000115 "A cell that initiates an electrical signal and passes that signal to another cell."^^xsd:string ;
#     ns3:normalizedInformationContent 41.276404163608092 ;
#     ns3:referenceCount 6879 ;
#     ns2:hasOBONamespace "cell"^^xsd:string ;
#     rdfs:isDefinedBy ns1:cl.owl ;
#     rdfs:subClassOf ns1:CL_0000211 .
#
# ns1:CL_0000540 a owl:Class ;
#     rdfs:label "neuron"^^xsd:string ;
#     ns1:IAO_0000115 "The basic cellular unit of nervous tissue. Each neuron consists of a body, an axon, and dendrites. Their purpose is to receive, conduct, and transmit impulses in the nervous system."^^xsd:string ;
#     ns3:normalizedInformationContent 41.277370330071577 ;
#     ns3:referenceCount 6878 ;
#     ns2:hasDbXref "BTO:0000938"^^xsd:string,
#         "CALOHA:TS-0683"^^xsd:string,

# %%
# !runoak  -i ubergraph: extract-triples CL:0000540 | grep -A10 owl:Class | head -50
# Out:
# ns1:CARO_0010004 a owl:Class ;
#     ns2:normalizedInformationContent 2.9759597027374216 ;
#     ns2:referenceCount 2189874 ;
#     rdfs:isDefinedBy ns1:caro.owl ;
#     rdfs:subClassOf ns1:CARO_0001010,
#         ns1:COB_0000022,
#         ns1:NCBITaxon_1,
#         ns1:OBI_0100026 ;
#     owl:equivalentClass ns1:COB_0000118 .
#
# ns1:CL_0000255 a owl:Class ;
#     rdfs:label "eukaryotic cell"^^xsd:string ;
#     ns2:normalizedInformationContent 38.474125635088676 ;
#     ns2:referenceCount 10487 ;
#     ns3:hasOBONamespace "cell"^^xsd:string ;
#     rdfs:isDefinedBy ns1:cl.owl ;
#     rdfs:subClassOf ns1:CARO_0000013,
#         ns1:CL_0000003,
#         ns1:COB_0000018 ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf [ ] ] .
#
# ns1:CL_0000393 a owl:Class ;
#     rdfs:label "electrically responsive cell"^^xsd:string ;
#     ns1:IAO_0000115 "A cell whose function is determined by its response to an electric signal."^^xsd:string ;
#     ns2:normalizedInformationContent 40.249883390245465 ;
#     ns2:referenceCount 8028 ;
#     ns3:hasOBONamespace "cell"^^xsd:string ;
#     rdfs:isDefinedBy ns1:cl.owl ;
#     rdfs:subClassOf ns1:CL_0000211 .
#
# ns1:CL_0000404 a owl:Class ;
#     rdfs:label "electrically signaling cell"^^xsd:string ;
#     ns1:IAO_0000115 "A cell that initiates an electrical signal and passes that signal to another cell."^^xsd:string ;
#     ns2:normalizedInformationContent 41.276404163608092 ;
#     ns2:referenceCount 6879 ;
#     ns3:hasOBONamespace "cell"^^xsd:string ;
#     rdfs:isDefinedBy ns1:cl.owl ;
#     rdfs:subClassOf ns1:CL_0000211 .
#
# ns1:CL_0000540 a owl:Class ;
#     rdfs:label "neuron"^^xsd:string ;
#     ns1:IAO_0000115 "The basic cellular unit of nervous tissue. Each neuron consists of a body, an axon, and dendrites. Their purpose is to receive, conduct, and transmit impulses in the nervous system."^^xsd:string ;
#     ns2:normalizedInformationContent 41.277370330071577 ;
#     ns2:referenceCount 6878 ;
#     ns3:hasDbXref "BTO:0000938"^^xsd:string,
#         "CALOHA:TS-0683"^^xsd:string,
#         "FBbt:00005106"^^xsd:string,
#         "FMA:54527"^^xsd:string,
#         "VHOG:0001483"^^xsd:string,

# %%
# !runoak -i ubergraph: search "non-motile cilium" | head -20
# Out:
# WARNING:root:Multiple labels for MAXO:0000221 = nonsteroidal anti-inflammatory agent therapy != NSAID therapy
# WARNING:root:Multiple labels for MAXO:0000193 = non-opioid analgesics agent therapy != non-opioid analgesic therapy
# NCIT:C26747 ! Type 2 Diabetes Mellitus
# NCIT:C2917 ! Carcinoma In Situ
# NCIT:C2924 ! Breast Ductal Carcinoma In Situ
# NCIT:C3172 ! Myeloid Leukemia
# NCIT:C3641 ! Stage 0 Breast Cancer AJCC v6 and v7
# NCIT:C39854 ! Non-Invasive Urothelial Neoplasm
# NCIT:C4018 ! Breast Lobular Carcinoma In Situ
# NCIT:C4195 ! Breast Ductal Carcinoma In Situ and Lobular Carcinoma In Situ
# NCIT:C3211 ! Non-Hodgkin Lymphoma
# NCIT:C27659 ! Non-Neoplastic Laryngeal Disorder
# NCIT:C36027 ! Non-Invasive Lesion
# NCIT:C27555 ! Non-Neoplastic Skin Disorder
# NCIT:C27557 ! Non-Neoplastic Lung Disorder
# NCIT:C27604 ! Non-Neoplastic Eye Disorder
# NCIT:C35741 ! Non-Neoplastic Heart Disorder
# NCIT:C36110 ! Non-Measurable Lesion
# NCIT:C27565 ! Non-Neoplastic Endocrine Disorder
# NCIT:C27572 ! Non-Neoplastic Bone Disorder
# NCIT:C27600 ! Non-Neoplastic Kidney Disorder
# NCIT:C27601 ! Non-Neoplastic Bladder Disorder

# %%
# !runoak -i ubergraph:cl search "non-motile cilium" | head -20
# Out:
# CL:0000055 ! non-terminally differentiated cell
# CL:0000072 ! non-branched duct epithelial cell
# CL:0000158 ! club cell
# CL:0000192 ! smooth muscle cell
# CL:0000219 ! motile cell
# CL:0000225 ! anucleate cell
# CL:0000238 ! non keratinizing barrier epithelial cell
# CL:0000332 ! obsolete atrichoblast
# CL:0000344 ! obsolete non-visual cell (sensu Vertebrata)
# CL:0000875 ! non-classical monocyte
# CL:0000917 ! Tc1 cell
# CL:0000918 ! Tc2 cell
# CL:0000970 ! unswitched memory B cell
# CL:0001040 ! non-terminally differentiated osteoblast
# CL:0001051 ! CD4-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell
# CL:0001052 ! CD8-positive, CXCR3-negative, CCR6-negative, alpha-beta T cell
# CL:0002058 ! Gr1-low non-classical monocyte
# CL:0002128 ! Tc17 cell
# CL:0002226 ! non-nucleated secondary lens fiber
# CL:0002304 ! non-pigmented ciliary epithelial cell

# %% [markdown]
# ## BioPortal
#
# This implementation is ideal for use cases involving
#
#  - search over diverse multiple ontologies
#  - extracting text mappings across broad ontologies
#  - text annotation

# %%
# !runoak -i bioportal: search "tentacle" | head -20
# Out:
# BTO:0001357 ! tentacle
# http://purl.jp/bio/4/id/200906071014668510 ! tentacle
# CEPH:0000256 ! tentacle
# http://www.projecthalo.com/aura#Tentacle ! Tentacle
# CEPH:0000256 ! tentacle
# CTENO:0000018 ! tentacle
# BSA:0000109 ! tentacle
# CLYH:1000005 ! tentacle
# UBERON:0013206 ! nasal tentacle
# UBERON:0013206 ! nasal tentacle
# CEPH:0000259 ! tentacle pocket
# CEPH:0000261 ! tentacle thickness
# CEPH:0000257 ! tentacle absence
# CEPH:0000258 ! tentacle pad
# CTENO:0000121 ! tentacle sheath
# CTENO:0000120 ! tentacle epithelium
# CTENO:0000152 ! tentacle apparatus
# CTENO:0000143 ! tentacle bulb
# AMPHX:1000339 ! velar tentacle
# CLYH:1000004 ! tentacle system

# %%
# !runoak -i bioportal: term-mappings CTENO:0000018 -O sssom
# Out:
# # curie_map: {}
# # license: UNSPECIFIED
# # mapping_set_id: temp
# subject_id	predicate_id	object_id	match_type	mapping_provider	mapping_tool
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/CEPH_0000256	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/CEPH_0000256	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/CEPH_0000256	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.jp/bio/4/id/200906071014668510	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/CLYH_1000005	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BTO_0001357	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://purl.obolibrary.org/obo/BSA_0000109	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM
# http://purl.obolibrary.org/obo/CTENO_0000018	skos:closeMatch	http://www.projecthalo.com/aura#Tentacle	Unspecified	http://data.bioontology.org/metadata/Mapping	LOOM

# %%
# !runoak -i bioportal: term-mappings CTENO:0000018 -O sssom -o output/tentacle-bioportal.sssom.tsv

# %%
import pandas as pd

# %%
pd.read_csv('output/tentacle-bioportal.sssom.tsv', sep='\t', comment='#')
# Out:
#                                       subject_id     predicate_id  \
# 0   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 1   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 2   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 3   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 4   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 5   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 6   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 7   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 8   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 9   http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 10  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 11  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 12  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 13  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 14  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 15  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 16  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
# 17  http://purl.obolibrary.org/obo/CTENO_0000018  skos:closeMatch
#
#                                       object_id   match_type  \
# 0    http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 1   http://purl.obolibrary.org/obo/CEPH_0000256  Unspecified
# 2   http://purl.obolibrary.org/obo/CEPH_0000256  Unspecified
# 3   http://purl.obolibrary.org/obo/CEPH_0000256  Unspecified
# 4    http://purl.jp/bio/4/id/200906071014668510  Unspecified
# 5   http://purl.obolibrary.org/obo/CLYH_1000005  Unspecified
# 6    http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 7    http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 8    http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 9    http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 10   http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 11   http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 12   http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 13   http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 14   http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 15   http://purl.obolibrary.org/obo/BTO_0001357  Unspecified
# 16   http://purl.obolibrary.org/obo/BSA_0000109  Unspecified
# 17              http://www.projecthalo.com/aura          NaN
#
#                                 mapping_provider mapping_tool
# 0   http://data.bioontology.org/metadata/Mapping         LOOM
# 1   http://data.bioontology.org/metadata/Mapping         LOOM
# 2   http://data.bioontology.org/metadata/Mapping         LOOM
# 3   http://data.bioontology.org/metadata/Mapping         LOOM
# 4   http://data.bioontology.org/metadata/Mapping         LOOM
# 5   http://data.bioontology.org/metadata/Mapping         LOOM
# 6   http://data.bioontology.org/metadata/Mapping         LOOM
# 7   http://data.bioontology.org/metadata/Mapping         LOOM
# 8   http://data.bioontology.org/metadata/Mapping         LOOM
# 9   http://data.bioontology.org/metadata/Mapping         LOOM
# 10  http://data.bioontology.org/metadata/Mapping         LOOM
# 11  http://data.bioontology.org/metadata/Mapping         LOOM
# 12  http://data.bioontology.org/metadata/Mapping         LOOM
# 13  http://data.bioontology.org/metadata/Mapping         LOOM
# 14  http://data.bioontology.org/metadata/Mapping         LOOM
# 15  http://data.bioontology.org/metadata/Mapping         LOOM
# 16  http://data.bioontology.org/metadata/Mapping         LOOM
# 17                                           NaN          NaN

# %%
# !runoak -i bioportal: annotate "cephalopods may have tentacular clubs on the end of their tentacles"
# Out:
# object_id: MESH/D049830
# object_label: Cephalopoda
# object_source: https://data.bioontology.org/ontologies/MESH
# match_type: SYN
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: NCBITaxon:6605
# object_label: Cephalopoda
# object_source: https://data.bioontology.org/ontologies/ERO
# match_type: SYN
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: http://localhost/plosthes.2017-1#3780
# object_label: Cephalopods
# object_source: https://data.bioontology.org/ontologies/PLOSTHES
# match_type: PREF
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: http://id.nlm.nih.gov/mesh/D049830
# object_label: Cephalopoda
# object_source: https://data.bioontology.org/ontologies/MDM
# match_type: SYN
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: http://uri.neuinfo.org/nif/nifstd/birnlex_519
# object_label: Cephalopods
# object_source: https://data.bioontology.org/ontologies/NIFSTD
# match_type: PREF
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: http://bioontology.org/projects/ontologies/birnlex#birnlex_519
# object_label: Cephalopods
# object_source: https://data.bioontology.org/ontologies/BIRNLEX
# match_type: PREF
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: NIBIOHN:NHNSFG:1010054
# object_label: Cephalopods
# object_source: https://data.bioontology.org/ontologies/FGNHNS
# match_type: PREF
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---
# object_id: TRAK:0001433
# object_label: possibly
# object_source: https://data.bioontology.org/ontologies/TRAK
# match_type: SYN
# subject_start: 13
# subject_end: 20
# subject_label: MAY HAVE
#
# ---
# object_id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C101282
# object_label: Have
# object_source: https://data.bioontology.org/ontologies/NCIT
# match_type: PREF
# subject_start: 17
# subject_end: 20
# subject_label: HAVE
#
# ---
# object_id: NCIT:C101282
# object_label: Have
# object_source: https://data.bioontology.org/ontologies/PREMEDONTO
# match_type: PREF
# subject_start: 17
# subject_end: 20
# subject_label: HAVE
#
# ---
# object_id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C89277
# object_label: Possess
# object_source: https://data.bioontology.org/ontologies/NCIT
# match_type: SYN
# subject_start: 17
# subject_end: 20
# subject_label: HAVE
#
# ---
# object_id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C17406
# object_label: Endoglin
# object_source: https://data.bioontology.org/ontologies/NCIT
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: ZFA:0000340
# object_label: dorsal entopeduncular nucleus of ventral telencephalon
# object_source: https://data.bioontology.org/ontologies/ZFA
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://purl.allotrope.org/ontologies/process#AFP_0003286
# object_label: end
# object_source: https://data.bioontology.org/ontologies/AFO
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://www.limics.fr/ontologies/menelastop#end
# object_label: fin
# object_source: https://data.bioontology.org/ontologies/TOP-MENELAS
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: PR:P17813
# object_label: endoglin (human)
# object_source: https://data.bioontology.org/ontologies/PR
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://sbmi.uth.tmc.edu/ontology/ochv#C0444930
# object_label: end
# object_source: https://data.bioontology.org/ontologies/OCHV
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://identifiers.org/ncbigene/2022
# object_label: ENG
# object_source: https://data.bioontology.org/ontologies/GEXO
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: SNOMEDCT/261782000
# object_label: End
# object_source: https://data.bioontology.org/ontologies/SNOMEDCT
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: NCIT:C25496
# object_label: End
# object_source: https://data.bioontology.org/ontologies/PREMEDONTO
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://purl.allotrope.org/ontologies/result#AFR_0001626
# object_label: stop command
# object_source: https://data.bioontology.org/ontologies/AFO
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://sbmi.uth.tmc.edu/ontology/ochv#35491
# object_label: '35491'
# object_source: https://data.bioontology.org/ontologies/OCHV
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: PR:000001345
# object_label: endoglin
# object_source: https://data.bioontology.org/ontologies/PR
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://www.projecthalo.com/aura#End
# object_label: End
# object_source: https://data.bioontology.org/ontologies/AURA
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: OGG:3000002022
# object_label: ENG
# object_source: https://data.bioontology.org/ontologies/OGG
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C25496
# object_label: End
# object_source: https://data.bioontology.org/ontologies/NCIT
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: LNC/LP190655-3
# object_label: end
# object_source: https://data.bioontology.org/ontologies/LOINC
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://www.limics.fr/ontologies/ontoparonnoy#Fin
# object_label: fin
# object_source: https://data.bioontology.org/ontologies/ONTOPARON
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://identifiers.org/hgnc/3349
# object_label: ENG
# object_source: https://data.bioontology.org/ontologies/HGNC-NR
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: https://identifiers.org/ncbigene/2022
# object_label: ENG (Hsap)
# object_source: https://data.bioontology.org/ontologies/PCL
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: HL7/C1561490
# object_label: end
# object_source: https://data.bioontology.org/ontologies/HL7
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: https://w3id.org/mixs/vocab/TrainStopLocEnum#end
# object_label: end
# object_source: https://data.bioontology.org/ontologies/MIXS
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: NCBIGene:2022
# object_label: ENG
# object_source: https://data.bioontology.org/ontologies/CCO
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://vocabs.lter-europe.net/EnvThes/10319
# object_label: end
# object_source: https://data.bioontology.org/ontologies/ENVTHES
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: RCD/X90XL
# object_label: End
# object_source: https://data.bioontology.org/ontologies/RCD
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://www.w3.org/ns/prov#End
# object_label: End
# object_source: https://data.bioontology.org/ontologies/CHEAR
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C51541
# object_label: ENG wt Allele
# object_source: https://data.bioontology.org/ontologies/NCIT
# match_type: SYN
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: OGG:3000888190
# object_label: end
# object_source: https://data.bioontology.org/ontologies/OHPI
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: GAZ:00633718
# object_label: End
# object_source: https://data.bioontology.org/ontologies/GAZ
# match_type: PREF
# subject_start: 46
# subject_end: 48
# subject_label: END
#
# ---
# object_id: http://neuromorpho.org/ontologies/archiveH.owl#NMOOt_1475
# object_label: Their
# object_source: https://data.bioontology.org/ontologies/NMOBR
# match_type: PREF
# subject_start: 53
# subject_end: 57
# subject_label: THEIR
#
# ---
# object_id: MooccuA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/MOOCCUADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: MoocciA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/MOOCCIADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: PhmammA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/PHMAMMADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: PhfumiA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/PHFUMIADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: HaroreA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/HAROREADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: CisaviA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/CISAVIADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: HaauraA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/HAAURAADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: CiinteA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/CIINTEADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---
# object_id: MooculA:0000741
# object_label: Tentacles
# object_source: https://data.bioontology.org/ontologies/MOOCULADO
# matches_whole_text: true
# match_type: PREF
# subject_start: 59
# subject_end: 67
# subject_label: TENTACLES
#
# ---

# %%
# !runoak -i bioportal:ceph annotate "cephalopods may have tentacular clubs on the end of their tentacles"
# Out:
# object_id: NCBITaxon:6605
# object_label: Cephalopoda
# object_source: https://data.bioontology.org/ontologies/CEPH
# match_type: SYN
# subject_start: 1
# subject_end: 11
# subject_label: CEPHALOPODS
#
# ---

# %% [markdown]
# ## Pronto (for local files
#
# Pronto can be used for local files in obo format, or rdf/xml following an OBO-like profile; also for the same files hosted on http://obofoundry.org

# %% [markdown]
# ## Sqlite
#
# See [semantic-sql](https://github.com/INCATools/semantic-sql)

# %%
# !curl -L -s https://s3.amazonaws.com/bbop-sqlite/envo.db > input/envo.db

# %%
# !runoak -i input/envo.db ancestors -p i,p river
# Out:
# id	label
# ENVO:00000022	river
# rdfs:subClassOf	None
# ENVO:00000023	stream
# ENVO:00000029	watercourse
# ENVO:01000618	lotic water body
# ENVO:00000063	water body
# BFO:0000050	part of
# ENVO:01000819	hydrosphere
# ENVO:01000685	water mass
# ENVO:01001476	body of liquid
# ENVO:01001477	liquid astronomical body part
# ENVO:01001479	fluid astronomical body part
# ENVO:01001784	compound astronomical body part
# ENVO:01000813	astronomical body part
# ENVO:01000799	astronomical body
# BFO:0000024	fiat object part
# BFO:0000040	material entity
# BFO:0000004	independent continuant
# BFO:0000002	continuant
# BFO:0000001	entity
# ENVO:01000804	astronomical object
# BFO:0000030	object

# %%
# !runoak -i input/envo.db descendants -p i,p river | runoak -i input/envo.db info -O obo -
# Out:
# [Term]
# id: ENVO:00000022
# name: river
# def: "A stream which, through permanent or seasonal flow processes, moves from elevated land towards lower elevations through a definite channel and empties either into a sea, lake, or another river or ends on land as bed seepage and evapotranspiration exceed water supply." []
# xref: EcoLexicon:river
# xref: FTT:1179
# xref: FTT:251
# xref: SPIRE:River
# xref: SWEETRealm:River
# xref: TGN:21105
#
#
# [Term]
# id: ENVO:00000059
# name: underground river
# def: "A river that is under the surface of the Earth." []
# xref: TGN:21187
# xref: https://en.wikipedia.org/wiki/Underground_river
#
#
# [Term]
# id: ENVO:00000101
# name: delta
# def: "A tract of alluvium formed at the mouth of a river where the deposition ofsome of its load exceeds its rate of removal, crossed by the divergent channels (distributaries) of the river." []
# xref: EcoLexicon:delta
# xref: FTT:97
# xref: Geonames:T.DLTA
# xref: SWEETRealm:Delta
# xref: TGN:21164
# xref: TGN:21422
# xref: https://en.wikipedia.org/wiki/Delta
#
#
# [Term]
# id: ENVO:00000386
# name: river mouth
# def: "The end of a stream where it enters a standing water body such as a lake, sea or ocean." []
# xref: TGN:21156
# xref: https://en.wikipedia.org/wiki/River_mouth
#
#
# [Term]
# id: ENVO:01000297
# name: freshwater river
# def: "A river where fresh water flows." []
#
#
# [Term]
# id: ENVO:01000599
# name: river water
#
#
# [Term]
# id: ENVO:01000908
# name: geothermally heated river
# def: "A river which is heated by geothermal processes such as heat exchange with lava or hydrothermal percolation." []
#
#
# [Term]
# id: ENVO:03600015
# name: polluted river
# def: "A river which has elevated levels of contaminants." []

# %%
# !runoak -i ../db/cl.db search "neuron" | head
# Out:
# CL:0000540 ! neuron

# %%
# !runoak -i ../db/pato.db validate -o output/pato.validation.tsv | head
# Out:
# type: http://www.w3.org/ns/shacl#MinCountConstraintComponent
# subject: BFO:0000027
# severity: ERROR
# predicate: rdfs:label
# info: Missing slot (label) for BFO:0000027
#
# type: http://www.w3.org/ns/shacl#MinCountConstraintComponent
# subject: CARO:0000000
# severity: ERROR
# predicate: rdfs:label

# %%
pd.read_csv('output/pato.validation.tsv', sep='\t')
# Out:
#                                                   type         subject  \
# 0    http://www.w3.org/ns/shacl#MinCountConstraintC...     BFO:0000027
# 1    http://www.w3.org/ns/shacl#MinCountConstraintC...    CARO:0000000
# 2    http://www.w3.org/ns/shacl#MinCountConstraintC...     NBO:0000073
# 3    http://www.w3.org/ns/shacl#MinCountConstraintC...  NCBITaxon:3176
# 4    http://www.w3.org/ns/shacl#MinCountConstraintC...  NCBITaxon:3378
# ..                                                 ...             ...
# 195  http://www.w3.org/ns/shacl#DatatypeConstraintC...    PATO:0000694
# 196  http://www.w3.org/ns/shacl#DatatypeConstraintC...    PATO:0000700
# 197  http://www.w3.org/ns/shacl#DatatypeConstraintC...    PATO:0000706
# 198  http://www.w3.org/ns/shacl#DatatypeConstraintC...    PATO:0000708
# 199  http://www.w3.org/ns/shacl#DatatypeConstraintC...    PATO:0000967
#
#     severity instantiates             predicate object object_str source  \
# 0      ERROR         None            rdfs:label   None       None   None
# 1      ERROR         None            rdfs:label   None       None   None
# 2      ERROR         None            rdfs:label   None       None   None
# 3      ERROR         None            rdfs:label   None       None   None
# 4      ERROR         None            rdfs:label   None       None   None
# ..       ...          ...                   ...    ...        ...    ...
# 195    ERROR         None  oio:hasAlternativeId   None       None   None
# 196    ERROR         None  oio:hasAlternativeId   None       None   None
# 197    ERROR         None  oio:hasAlternativeId   None       None   None
# 198    ERROR         None  oio:hasAlternativeId   None       None   None
# 199    ERROR         None  oio:hasAlternativeId   None       None   None
#
#                                                   info
# 0                 Missing slot (label) for BFO:0000027
# 1                Missing slot (label) for CARO:0000000
# 2                 Missing slot (label) for NBO:0000073
# 3              Missing slot (label) for NCBITaxon:3176
# 4              Missing slot (label) for NCBITaxon:3378
# ..                                                 ...
# 195  Incorrect datatype for has_alternative_id expe...
# 196  Incorrect datatype for has_alternative_id expe...
# 197  Incorrect datatype for has_alternative_id expe...
# 198  Incorrect datatype for has_alternative_id expe...
# 199  Incorrect datatype for has_alternative_id expe...
#
# [200 rows x 9 columns]
