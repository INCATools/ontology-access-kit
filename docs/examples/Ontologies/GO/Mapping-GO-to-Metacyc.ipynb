# %% [markdown]
# # Mapping using OAK: mapping GO to MetaCyc
#
# This illustrates the use of `lexmatch` to map between GO and MetaCyc
#
# First we set up a convenience alias:

# %%
alias go runoak -i sqlite:obo:go

# %% [markdown]
# Next we will use `--help` to get the inline documentation on `lexmatch`

# %%
go lexmatch --help
# Out:
# Usage: runoak lexmatch [OPTIONS] [TERMS]...
#
#   Performs lexical matching between pairs of terms in one more more
#   ontologies.
#
#   Examples:
#
#       runoak -i foo.obo lexmatch -o foo.sssom.tsv
#
#   In this example, the input ontology file is assumed to contain all pairs of
#   terms to be mapped.
#
#   It is more common to map between all pairs of terms in two ontology files.
#   In this case, you can merge the ontologies using a tool like ROBOT; or,  to
#   avoid a merge preprocessing step, use the --addl (-a) option to specify a
#   second ontology file.
#
#       runoak -i foo.obo --add bar.obo lexmatch -o foo.sssom.tsv
#
#   By default, this command will compare all terms in all ontologies. You can
#   use the OAK term query syntax to pass in the set of all terms to be
#   compared.
#
#   For example, to compare all terms in union of FOO and BAR namespaces:
#
#       runoak -i foo.obo --add bar.obo lexmatch -o foo.sssom.tsv i^FOO: i^BAR:
#
#   All members of the set are compared (including FOO to FOO matches and BAR to
#   BAR matches), omitting trivial reciprocal matches.
#
#   Use an "@" separator between two queries to feed in two explicit sets:
#
#       runoak -i foo.obo --add bar.obo lexmatch -o foo.sssom.tsv i^FOO: @
#       i^BAR:
#
#   ALGORITHM: lexmatch implements a simple algorithm:
#
#   - create a lexical index, keyed by normalized strings of labels, synonyms -
#   report all pairs of entities that have the same key
#
#   The lexical index can be exported (in native YAML) using -L:
#
#       runoak -i foo.obo lexmatch -L foo.index.yaml -o foo.sssom.tsv
#
#   Note: if you run the above command a second time it will be faster as the
#   index will be reused.
#
#   RULES: Using custom rules:
#
#       runoak  -i foo.obo lexmatch -R match_rules.yaml -L foo.index.yaml -o
#       foo.sssom.tsv
#
#   Full documentation:
#
#   - https://incatools.github.io/ontology-access-
#   kit/src/oaklib.utilities.lexical.lexical_indexer.html# module-
#   oaklib.utilities.lexical.lexical_indexer
#
# Options:
#   -R, --rules-file TEXT           path to rules file. Conforms to
#                                   rules_datamodel.        e.g.
#                                   https://github.com/INCATools/ontology-
#                                   access-
#                                   kit/blob/main/tests/input/matcher_rules.yaml
#   --add-labels / --no-add-labels  Populate empty labels with URI fragments or
#                                   CURIE local IDs, for ontologies that use
#                                   semantic IDs  [default: no-add-labels]
#   -L, --lexical-index-file TEXT   path to lexical index. This is recreated
#                                   each time unless --no-recreate is passed
#   --recreate / --no-recreate      if true and lexical index is specified,
#                                   always recreate, otherwise load from index
#                                   [default: recreate]
#   --ensure-strict-prefixes / --no-ensure-strict-prefixes
#                                   Clean prefix map and mappings before
#                                   generating an output.  [default: ensure-
#                                   strict-prefixes]
#   -o, --output FILENAME           Output file, e.g. obo file
#   --help                          Show this message and exit.

# %% [markdown]
# ## Using lexmatch
#
# Here we assume a prepared yeastpathways file in an ontology format (yp.obo)
#
# To align we will specify this file with the `-a` option, for additional ontologies.
#
# To restrict the mapping set to those between GO and MetaCyc we pass two argument lists which
# are OAK selector queries
#
# - `i^GO:` all terms with an ID that starts with `GO:`
# - `i^MetaCyc:` all terms with an ID that starts with `MetaCyc:`
#
# We will choose SSSOM as the output format (default). Note SSSOM is strict about all IDs also being expandable
# to URIs, and currently `MetaCyc` isn't in the default OBO list, so we pass this on the command line:

# %%
go --prefix MetaCyc=http://identifiers.org/MetaCyc/ -a inputs/yp.obo lexmatch i^GO: @ i^MetaCyc: -o output/go-to-yp.sssom.tsv
# Out:
# WARNING:root:Skipping <urn:swrl#A> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#B> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#C> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#D> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#a1> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#a2> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#d> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#e> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#eff> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#g1> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#g2> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#in> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#mf2> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#mf> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#p> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#w> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#x> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#y> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#z> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl:var#x> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl:var#y> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl:var#z> as it is not a valid CURIE

# %% [markdown]
# Next we will use pandas to explore and view the table

# %%
import pandas as pd

# %%
df = pd.read_csv("output/go-to-yp.sssom.tsv", comment="#", sep="\t")
df
# Out:
#     subject_id                                      subject_label  \
# 0   GO:0005978                      glycogen biosynthetic process
# 1   GO:0005980                         glycogen catabolic process
# 2   GO:0005987                          sucrose catabolic process
# 3   GO:0005993                        trehalose catabolic process
# 4   GO:0005998                         xylulose catabolic process
# 5   GO:0006001                         fructose catabolic process
# 6   GO:0006031                        chitin biosynthetic process
# 7   GO:0006048       UDP-N-acetylglucosamine biosynthetic process
# 8   GO:0006068                          ethanol catabolic process
# 9   GO:0006097                                   glyoxylate cycle
# 10  GO:0006098                            pentose-phosphate shunt
# 11  GO:0006114                      glycerol biosynthetic process
# 12  GO:0006530                       asparagine catabolic process
# 13  GO:0006532                     aspartate biosynthetic process
# 14  GO:0006550                       isoleucine catabolic process
# 15  GO:0006552                          leucine catabolic process
# 16  GO:0006565                         L-serine catabolic process
# 17  GO:0006567                        threonine catabolic process
# 18  GO:0006569                       tryptophan catabolic process
# 19  GO:0006571                      tyrosine biosynthetic process
# 20  GO:0006574                           valine catabolic process
# 21  GO:0006597                      spermine biosynthetic process
# 22  GO:0006661          phosphatidylinositol biosynthetic process
# 23  GO:0006696                    ergosterol biosynthetic process
# 24  GO:0006750                   glutathione biosynthetic process
# 25  GO:0006751                      glutathione catabolic process
# 26  GO:0006853                                  carnitine shuttle
# 27  GO:0008654                  phospholipid biosynthetic process
# 28  GO:0009086                    methionine biosynthetic process
# 29  GO:0009094               L-phenylalanine biosynthetic process
# 30  GO:0009102                        biotin biosynthetic process
# 31  GO:0009228                      thiamine biosynthetic process
# 32  GO:0009423                    chorismate biosynthetic process
# 33  GO:0016024            CDP-diacylglycerol biosynthetic process
# 34  GO:0019240                    citrulline biosynthetic process
# 35  GO:0019309                          mannose catabolic process
# 36  GO:0019354                      siroheme biosynthetic process
# 37  GO:0019388                        galactose catabolic process
# 38  GO:0019427       acetyl-CoA biosynthetic process from acetate
# 39  GO:0019509      L-methionine salvage from methylthioadenosine
# 40  GO:0019563                         glycerol catabolic process
# 41  GO:0030497                              fatty acid elongation
# 42  GO:0032958            inositol phosphate biosynthetic process
# 43  GO:0033014                  tetrapyrrole biosynthetic process
# 44  GO:0034079                    butanediol biosynthetic process
# 45  GO:0036197                    zymosterol biosynthetic process
# 46  GO:0045151                       acetoin biosynthetic process
# 47  GO:0046654              tetrahydrofolate biosynthetic process
# 48  GO:0046854  phosphatidylinositol phosphate biosynthetic pr...
# 49  GO:0051596                    methylglyoxal catabolic process
# 50  GO:0070485  dehydro-D-arabinono-1,4-lactone biosynthetic p...
# 51  GO:0071269                L-homocysteine biosynthetic process
#
#        predicate_id                       object_id  \
# 0   skos:closeMatch              MetaCyc:PWY3O-4031
# 1   skos:closeMatch      MetaCyc:GLYCOCAT-YEAST-PWY
# 2   skos:closeMatch           MetaCyc:SUCUTIL-PWY-2
# 3   skos:closeMatch        MetaCyc:TREDEG-YEAST-PWY
# 4   skos:closeMatch                 MetaCyc:PWY3O-5
# 5   skos:closeMatch                 MetaCyc:PWY3O-0
# 6   skos:closeMatch                MetaCyc:PWY3O-15
# 7   skos:closeMatch     MetaCyc:UDPNAGSYN-YEAST-PWY
# 8   skos:closeMatch              MetaCyc:PWY3O-4300
# 9   skos:closeMatch       MetaCyc:GLYOXYLATE-BYPASS
# 10  skos:closeMatch           MetaCyc:PENTOSE-P-PWY
# 11  skos:closeMatch                MetaCyc:PWY3O-48
# 12  skos:closeMatch     MetaCyc:ASPARAGINE-DEG2-PWY
# 13  skos:closeMatch              MetaCyc:ASPBIO-PWY
# 14  skos:closeMatch              MetaCyc:PWY3O-4109
# 15  skos:closeMatch              MetaCyc:PWY3O-4112
# 16  skos:closeMatch              MetaCyc:SERDEG-PWY
# 17  skos:closeMatch           MetaCyc:THREOCAT2-PWY
# 18  skos:closeMatch               MetaCyc:PWY3O-214
# 19  skos:closeMatch              MetaCyc:PWY3O-4120
# 20  skos:closeMatch              MetaCyc:PWY3O-4105
# 21  skos:closeMatch           MetaCyc:ARGSPECAT-PWY
# 22  skos:closeMatch                 MetaCyc:PWY3O-3
# 23  skos:closeMatch             MetaCyc:PWY3O-31704
# 24  skos:closeMatch      MetaCyc:GLUTATHIONESYN-PWY
# 25  skos:closeMatch              MetaCyc:PWYQT-4432
# 26  skos:closeMatch                 MetaCyc:PWY3O-4
# 27  skos:closeMatch       MetaCyc:PHOSLIPSYN2-PWY-1
# 28  skos:closeMatch               MetaCyc:PWY3O-238
# 29  skos:closeMatch              MetaCyc:PWY3O-4153
# 30  skos:closeMatch    MetaCyc:BIOTIN-SYNTHESIS-PWY
# 31  skos:closeMatch                MetaCyc:PWY3O-17
# 32  skos:closeMatch               MetaCyc:ARO-PWY-1
# 33  skos:closeMatch               MetaCyc:PWY3O-103
# 34  skos:closeMatch         MetaCyc:CITRUL-BIO2-PWY
# 35  skos:closeMatch              MetaCyc:PWY3O-1743
# 36  skos:closeMatch              MetaCyc:PWY-5194-1
# 37  skos:closeMatch  MetaCyc:YEAST-GALACT-METAB-PWY
# 38  skos:closeMatch        MetaCyc:ACETATEUTIL2-PWY
# 39  skos:closeMatch                MetaCyc:PWY3O-64
# 40  skos:closeMatch   MetaCyc:AERO-GLYCEROL-CAT-PWY
# 41  skos:closeMatch        MetaCyc:FASYN-ELONG2-PWY
# 42  skos:closeMatch               MetaCyc:PWY3O-402
# 43  skos:closeMatch                MetaCyc:PWY3O-50
# 44  skos:closeMatch               MetaCyc:PWY3O-661
# 45  skos:closeMatch              MetaCyc:PWY-6074-1
# 46  skos:closeMatch               MetaCyc:PWY3O-335
# 47  skos:closeMatch                MetaCyc:PWY-6614
# 48  skos:closeMatch               MetaCyc:PWY3O-242
# 49  skos:closeMatch                 MetaCyc:PWY-901
# 50  skos:closeMatch               MetaCyc:PWY3O-6-1
# 51  skos:closeMatch                MetaCyc:PWY-5344
#
#                                     object_label   mapping_justification  \
# 0                          glycogen biosynthesis  semapv:LexicalMatching
# 1                            glycogen catabolism  semapv:LexicalMatching
# 2                            sucrose degradation  semapv:LexicalMatching
# 3                          trehalose degradation  semapv:LexicalMatching
# 4                           xylulose degradation  semapv:LexicalMatching
# 5                           fructose degradation  semapv:LexicalMatching
# 6                            chitin biosynthesis  semapv:LexicalMatching
# 7           UDP-N-acetylglucosamine biosynthesis  semapv:LexicalMatching
# 8                            ethanol degradation  semapv:LexicalMatching
# 9                               glyoxylate cycle  semapv:LexicalMatching
# 10                     pentose phosphate pathway  semapv:LexicalMatching
# 11                         glycerol biosynthesis  semapv:LexicalMatching
# 12                        asparagine degradation  semapv:LexicalMatching
# 13                        aspartate biosynthesis  semapv:LexicalMatching
# 14                        isoleucine degradation  semapv:LexicalMatching
# 15                           leucine degradation  semapv:LexicalMatching
# 16                          L-serine degradation  semapv:LexicalMatching
# 17                         threonine degradation  semapv:LexicalMatching
# 18                        tryptophan degradation  semapv:LexicalMatching
# 19                         tyrosine biosynthesis  semapv:LexicalMatching
# 20                            valine degradation  semapv:LexicalMatching
# 21                         spermine biosynthesis  semapv:LexicalMatching
# 22             phosphatidylinositol biosynthesis  semapv:LexicalMatching
# 23                       ergosterol biosynthesis  semapv:LexicalMatching
# 24                      glutathione biosynthesis  semapv:LexicalMatching
# 25                       glutathione degradation  semapv:LexicalMatching
# 26                             carnitine shuttle  semapv:LexicalMatching
# 27                     phospholipid biosynthesis  semapv:LexicalMatching
# 28                       methionine biosynthesis  semapv:LexicalMatching
# 29                    phenylalanine biosynthesis  semapv:LexicalMatching
# 30                           biotin biosynthesis  semapv:LexicalMatching
# 31                         thiamine biosynthesis  semapv:LexicalMatching
# 32                       chorismate biosynthesis  semapv:LexicalMatching
# 33               CDP-diacylglycerol biosynthesis  semapv:LexicalMatching
# 34                       citrulline biosynthesis  semapv:LexicalMatching
# 35                           mannose degradation  semapv:LexicalMatching
# 36                         siroheme biosynthesis  semapv:LexicalMatching
# 37                         galactose degradation  semapv:LexicalMatching
# 38                           acetate utilization  semapv:LexicalMatching
# 39                    methionine salvage pathway  semapv:LexicalMatching
# 40                          glycerol degradation  semapv:LexicalMatching
# 41                         fatty acid elongation  semapv:LexicalMatching
# 42               inositol phosphate biosynthesis  semapv:LexicalMatching
# 43                     tetrapyrrole biosynthesis  semapv:LexicalMatching
# 44                       butanediol biosynthesis  semapv:LexicalMatching
# 45                       zymosterol biosynthesis  semapv:LexicalMatching
# 46                          acetoin biosynthesis  semapv:LexicalMatching
# 47                 tetrahydrofolate biosynthesis  semapv:LexicalMatching
# 48   phosphatidylinositol phosphate biosynthesis  semapv:LexicalMatching
# 49                      methylglyoxal catabolism  semapv:LexicalMatching
# 50  dehydro-D-arabinono-1,4-lactone biosynthesis  semapv:LexicalMatching
# 51                   L-homocysteine biosynthesis  semapv:LexicalMatching
#
#    mapping_tool  confidence    subject_match_field object_match_field  \
# 0        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 1        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 2        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 3        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 4        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 5        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 6        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 7        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 8        oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 9        oaklib         0.5             rdfs:label         rdfs:label
# 10       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 11       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 12       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 13       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 14       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 15       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 16       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 17       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 18       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 19       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 20       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 21       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 22       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 23       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 24       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 25       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 26       oaklib         0.5             rdfs:label         rdfs:label
# 27       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 28       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 29       oaklib         0.5    oio:hasBroadSynonym         rdfs:label
# 30       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 31       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 32       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 33       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 34       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 35       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 36       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 37       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 38       oaklib         0.5  oio:hasRelatedSynonym         rdfs:label
# 39       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 40       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 41       oaklib         0.5             rdfs:label         rdfs:label
# 42       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 43       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 44       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 45       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 46       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 47       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 48       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 49       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 50       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 51       oaklib         0.5    oio:hasExactSynonym         rdfs:label
#
#                                     match_string
# 0                          glycogen biosynthesis
# 1                            glycogen catabolism
# 2                            sucrose degradation
# 3                          trehalose degradation
# 4                           xylulose degradation
# 5                           fructose degradation
# 6                            chitin biosynthesis
# 7           udp-n-acetylglucosamine biosynthesis
# 8                            ethanol degradation
# 9                               glyoxylate cycle
# 10                     pentose phosphate pathway
# 11                         glycerol biosynthesis
# 12                        asparagine degradation
# 13                        aspartate biosynthesis
# 14                        isoleucine degradation
# 15                           leucine degradation
# 16                          l-serine degradation
# 17                         threonine degradation
# 18                        tryptophan degradation
# 19                         tyrosine biosynthesis
# 20                            valine degradation
# 21                         spermine biosynthesis
# 22             phosphatidylinositol biosynthesis
# 23                       ergosterol biosynthesis
# 24                      glutathione biosynthesis
# 25                       glutathione degradation
# 26                             carnitine shuttle
# 27                     phospholipid biosynthesis
# 28                       methionine biosynthesis
# 29                    phenylalanine biosynthesis
# 30                           biotin biosynthesis
# 31                         thiamine biosynthesis
# 32                       chorismate biosynthesis
# 33               cdp-diacylglycerol biosynthesis
# 34                       citrulline biosynthesis
# 35                           mannose degradation
# 36                         siroheme biosynthesis
# 37                         galactose degradation
# 38                           acetate utilization
# 39                    methionine salvage pathway
# 40                          glycerol degradation
# 41                         fatty acid elongation
# 42               inositol phosphate biosynthesis
# 43                     tetrapyrrole biosynthesis
# 44                       butanediol biosynthesis
# 45                       zymosterol biosynthesis
# 46                          acetoin biosynthesis
# 47                 tetrahydrofolate biosynthesis
# 48   phosphatidylinositol phosphate biosynthesis
# 49                      methylglyoxal catabolism
# 50  dehydro-d-arabinono-1,4-lactone biosynthesis
# 51                   l-homocysteine biosynthesis

# %% [markdown]
# ## Enhancing mappings with a rule file
#
# Our first pass yielded 51 mappings (many of which were already present as xrefs). But those of us who know GO nomenclature know that this may be
# an undercount due to the fact GO uses unusual formal nomenclature not always used by biologists, or
# by the curators of MetaCyc.
#
# An example is the use of terms like `X catabolic process` whereas a biologist might just say `X catabolism`.
# Also for microbes a common term is `X degradation`
#
# Sometimes GO includes synonyms for these, *but this can't be relied on consistently*.
#
# We will use the *synonymizer* to auto-inject these synonyms.
#
# First we will curate a *rule file*, that looks like this:

# %%
# !cat inputs/go-match-rules.yaml
# Out:
# rules:
#   - description: default
#     postconditions:
#       predicate_id: skos:closeMatch
#       weight: 0.0
#
#   - description: exact to exact
#     preconditions:
#       subject_match_field_one_of:
#         - oio:hasExactSynonym
#         - rdfs:label
#         - skos:prefLabel
#       object_match_field_one_of:
#         - oio:hasExactSynonym
#         - rdfs:label
#         - skos:prefLabel
#     postconditions:
#       predicate_id: skos:exactMatch
#       weight: 2.0
#
#   - description: >-
#      label to label; note this is additive with the exact to exact rule,
#       so the score just represents an additional small boost
#     preconditions:
#       subject_match_field_one_of:
#         - rdfs:label
#       object_match_field_one_of:
#         - rdfs:label
#     postconditions:
#       predicate_id: skos:exactMatch
#       weight: 0.5
#
#   - description: xref match
#     preconditions:
#       subject_match_field_one_of:
#         - oio:hasDbXref
#         - skos:exactMatch
#       object_match_field_one_of:
#         - oio:hasDbXref
#         - skos:exactMatch
#     postconditions:
#       predicate_id: skos:exactMatch
#       weight: 4.0
#
#   - preconditions:
#       subject_match_field_one_of:
#         - oio:hasExactSynonym
#         - rdfs:label
#       object_match_field_one_of:
#         - oio:hasBroadSynonym
#     postconditions:
#       predicate_id: skos:broadMatch
#       weight: 2.0
#
#   - preconditions:
#       subject_match_field_one_of:
#         - oio:hasExactSynonym
#         - rdfs:label
#       object_match_field_one_of:
#         - oio:hasNarrowSynonym
#     postconditions:
#       predicate_id: skos:narrowMatch
#       weight: 2.0
#
#   - synonymizer:
#       the_rule: biosynthesis
#       match: r'biosynthetic process'
#       match_scope: "*"
#       replacement: "biosynthesis"
#   - synonymizer:
#       the_rule: metabolism
#       match: r'metabolic process'
#       match_scope: "*"
#       replacement: "metabolism"
#   - synonymizer:
#       the_rule: catabolism
#       match: r'catabolic process'
#       match_scope: "*"
#       replacement: "catabolism"
#   - synonymizer:
#       the_rule: degradation
#       match: r'catabolic process'
#       match_scope: "*"
#       replacement: "degradation"

# %% [markdown]
# Note the `synonymizer` replacement rules at the end.
#
# Next we will run lexmatch again, passing the rule file using `-R`

# %%
go --prefix MetaCyc=http://identifiers.org/MetaCyc/ -a inputs/yp.obo lexmatch -R inputs/go-match-rules.yaml i^GO: @ i^MetaCyc: -o output/go-to-yp.sssom.tsv
# Out:
# WARNING:root:Skipping <urn:swrl#A> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#B> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#C> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#D> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#a1> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#a2> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#d> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#e> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#eff> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#g1> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#g2> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#in> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#mf2> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#mf> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#p> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#w> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#x> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#y> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl#z> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl:var#x> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl:var#y> as it is not a valid CURIE
# WARNING:root:Skipping <urn:swrl:var#z> as it is not a valid CURIE

# %%
df = pd.read_csv("output/go-to-yp.sssom.tsv", comment="#", sep="\t")
df
# Out:
#             subject_id                                      subject_label  \
# 0           GO:0005978                      glycogen biosynthetic process
# 1           GO:0005978                      glycogen biosynthetic process
# 2           GO:0005980                         glycogen catabolic process
# 3           GO:0005980                         glycogen catabolic process
# 4           GO:0005987                          sucrose catabolic process
# ..                 ...                                                ...
# 78          GO:0070485  dehydro-D-arabinono-1,4-lactone biosynthetic p...
# 79          GO:0071269                L-homocysteine biosynthetic process
# 80          GO:0071269                L-homocysteine biosynthetic process
# 81  MetaCyc:PWY3O-4153                         phenylalanine biosynthesis
# 82  MetaCyc:PWY3O-4153                         phenylalanine biosynthesis
#
#         predicate_id                   object_id  \
# 0    skos:exactMatch          MetaCyc:PWY3O-4031
# 1    skos:exactMatch          MetaCyc:PWY3O-4031
# 2    skos:exactMatch  MetaCyc:GLYCOCAT-YEAST-PWY
# 3    skos:exactMatch  MetaCyc:GLYCOCAT-YEAST-PWY
# 4    skos:exactMatch       MetaCyc:SUCUTIL-PWY-2
# ..               ...                         ...
# 78   skos:exactMatch           MetaCyc:PWY3O-6-1
# 79   skos:exactMatch            MetaCyc:PWY-5344
# 80   skos:exactMatch            MetaCyc:PWY-5344
# 81  skos:narrowMatch                  GO:0009094
# 82  skos:narrowMatch                  GO:0009094
#
#                                     object_label   mapping_justification  \
# 0                          glycogen biosynthesis  semapv:LexicalMatching
# 1                          glycogen biosynthesis  semapv:LexicalMatching
# 2                            glycogen catabolism  semapv:LexicalMatching
# 3                            glycogen catabolism  semapv:LexicalMatching
# 4                            sucrose degradation  semapv:LexicalMatching
# ..                                           ...                     ...
# 78  dehydro-D-arabinono-1,4-lactone biosynthesis  semapv:LexicalMatching
# 79                   L-homocysteine biosynthesis  semapv:LexicalMatching
# 80                   L-homocysteine biosynthesis  semapv:LexicalMatching
# 81          L-phenylalanine biosynthetic process  semapv:LexicalMatching
# 82          L-phenylalanine biosynthetic process  semapv:LexicalMatching
#
#    mapping_tool  confidence  subject_match_field   object_match_field  \
# 0        oaklib    0.849779           rdfs:label           rdfs:label
# 1        oaklib    0.800000  oio:hasExactSynonym           rdfs:label
# 2        oaklib    0.849779           rdfs:label           rdfs:label
# 3        oaklib    0.800000  oio:hasExactSynonym           rdfs:label
# 4        oaklib    0.800000  oio:hasExactSynonym           rdfs:label
# ..          ...         ...                  ...                  ...
# 78       oaklib    0.800000  oio:hasExactSynonym           rdfs:label
# 79       oaklib    0.800000  oio:hasExactSynonym           rdfs:label
# 80       oaklib    0.849779           rdfs:label           rdfs:label
# 81       oaklib    0.800000           rdfs:label  oio:hasBroadSynonym
# 82       oaklib    0.800000           rdfs:label  oio:hasBroadSynonym
#
#                                     match_string  \
# 0                          glycogen biosynthesis
# 1                          glycogen biosynthesis
# 2                            glycogen catabolism
# 3                            glycogen catabolism
# 4                            sucrose degradation
# ..                                           ...
# 78  dehydro-d-arabinono-1,4-lactone biosynthesis
# 79                   l-homocysteine biosynthesis
# 80                   l-homocysteine biosynthesis
# 81                    phenylalanine biosynthesis
# 82                    phenylalanine biosynthesis
#
#                   subject_preprocessing                 object_preprocessing
# 0   semapv:RegularExpressionReplacement                                  NaN
# 1                                   NaN                                  NaN
# 2   semapv:RegularExpressionReplacement                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ..                                  ...                                  ...
# 78                                  NaN                                  NaN
# 79                                  NaN                                  NaN
# 80  semapv:RegularExpressionReplacement                                  NaN
# 81                                  NaN  semapv:RegularExpressionReplacement
# 82                                  NaN                                  NaN
#
# [83 rows x 13 columns]

# %%
This time we get 83 rows, including

# %% [markdown]
# To download: [output/go-to-yp.sssom.tsv](output/go-to-yp.sssom.tsv)

# %% [markdown]
# ## Future steps
#
# In future this tutorial will also include
#
# - methods to retrieve unmapped terms
# - ...
