# %%
# %alias chiro runoak -i sqlite:obo:chiro

# %%
chiro relationships -p obo:chiro#inhibitor_of
# Out:
# subject	subject_label	predicate	predicate_label	object	object_label
# CHEBI:22180	None	obo:chiro#inhibitor_of	None	GO:0003984	None
# CHEBI:22587	None	obo:chiro#inhibitor_of	None	NCBITaxon:10239	None
# CHEBI:23018	None	obo:chiro#inhibitor_of	None	GO:0004089	None
# CHEBI:23100	None	obo:chiro#inhibitor_of	None	GO:0006031	None
# CHEBI:23529	None	obo:chiro#inhibitor_of	None	GO:0009512	None
# CHEBI:23924	None	obo:chiro#inhibitor_of	None	<http://purl.obolibrary.org/GO_0003824>	None
# CHEBI:24319	None	obo:chiro#inhibitor_of	None	GO:0004356	None
# CHEBI:25355	None	obo:chiro#inhibitor_of	None	GO:0005746	None
# CHEBI:26087	None	obo:chiro#inhibitor_of	None	GO:0009767	None
# CHEBI:26088	None	obo:chiro#inhibitor_of	None	GO:0009522	None
# CHEBI:26089	None	obo:chiro#inhibitor_of	None	GO:0009523	None
# CHEBI:33282	None	obo:chiro#inhibitor_of	None	NCBITaxon:2	None
# CHEBI:35472	None	obo:chiro#inhibitor_of	None	GO:0006954	None
# CHEBI:35493	None	obo:chiro#inhibitor_of	None	GO:0001660	None
# ...
